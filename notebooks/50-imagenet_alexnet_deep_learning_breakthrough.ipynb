# %% [markdown]
# <img src="images/logo/selene-logo-640.png" style="max-height:75px;" alt="SELENE Logo" />**Disclaimer:** This Jupyter Notebook contains content generated with the assistance of AI. Verify critical information before relying on it.# ImageNet, AlexNet, and the 2012 BreakthroughImageNet provided a large labeled image benchmark; AlexNet's 2012 result demonstrated the impact of deep CNNs trained on GPUs.

# %% [markdown]
# ## Core IdeaAlexNet combined convolutions, ReLU activations, overlapping max pooling, augmentation, dropout, and multi-GPU training. Full ImageNet training is intentionally replaced here by an architecture inspection.

# %%
import torchfrom torch import nnmodel = nn.Sequential(    nn.Conv2d(3, 32, 5, stride=2, padding=2), nn.ReLU(), nn.MaxPool2d(3, 2),    nn.Conv2d(32, 64, 3, padding=1), nn.ReLU(), nn.MaxPool2d(3, 2),    nn.AdaptiveAvgPool2d((4, 4)), nn.Flatten(), nn.Dropout(0.5), nn.Linear(64 * 4 * 4, 10),)x = torch.randn(8, 3, 64, 64)print('output shape:', tuple(model(x).shape))print('parameters:', sum(p.numel() for p in model.parameters()))

# %% [markdown]
# ## Key TakeawaysThe breakthrough depended on data, computation, architecture, and engineering together, not one isolated technique.
