# %% [markdown]
# <img src="images/logo/selene-logo-640.png" style="max-height:75px;" alt="SELENE Logo" />**Disclaimer:** This Jupyter Notebook contains content generated with the assistance of AI. Verify critical information before relying on it.# Perceptron Learning AlgorithmThe perceptron is a binary linear classifier and one of the earliest trainable neural models.

# %% [markdown]
# ## Core IdeaFor a misclassified sample $(x_i,y_i)$ with $y_i\in\{-1,1\}$, update $w\leftarrow w+\eta y_i x_i$ and $b\leftarrow b+\eta y_i$.

# %%
import numpy as npX = np.array([[0,0], [0,1], [1,0], [1,1]], dtype=float)y = np.array([-1, -1, -1, 1])  # ANDw = np.zeros(2); b = 0.0for epoch in range(20):    errors = 0    for features, target in zip(X, y):        prediction = 1 if features @ w + b >= 0 else -1        if prediction != target:            w += target * features; b += target; errors += 1    if errors == 0: breakprint('weights:', w, 'bias:', b, 'predictions:', np.where(X @ w + b >= 0, 1, -1))

# %% [markdown]
# ## Key TakeawaysThe perceptron converges for linearly separable data but cannot solve non-linearly separable tasks such as XOR.
